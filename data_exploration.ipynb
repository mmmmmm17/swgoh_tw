# %%
#! git clone https://github.com/platzman/swgoh.help.python.git

# %%
exec(open('swgoh.help.python/swgohhelp.py').read())

# %%
import credentials

# %%
login = credentials.auth['login']
password = credentials.auth['password']

# %%
creds = settings(login, password,'123','abc')
client = SWGOHhelp(creds)

# %%
allycode = 984919835

player = client.get_data('player', allycode)
print(player)
# Out:
# [{'allyCode': 984919835, 'id': 'P1923416800', 'name': 'mmmmm', 'level': 85, 'titles': {'selected': 'PLAYERTITLE_GRANDARENA_CHALLENGE_GENERALKENOBI', 'unlocked': ['PLAYERTITLE_GRANDARENA_CHALLENGE_HANSOLO', 'PLAYERTITLE_DARKSIDEHISTORIAN', 'PLAYERTITLE_GRANDARENA_CHALLENGE_GENERALKENOBI', 'PLAYERTITLE_GENERAL', 'PLAYERTITLE_TANKTAMER', 'PLAYERTITLE_GRANDARENA_INTRO', 'PLAYERTITLE_HOLOTABLEHERO', 'PLAYERTITLE_GRANDARENA_ADVANCED', 'PLAYERTITLE_LOYAL_FRIEND', 'PLAYERTITLE_PITFIGHTER']}, 'guildRefId': 'G3984294299', 'guildName': 'JPI 501st', 'guildBannerColor': 'white_red', 'guildBannerLogo': 'guild_icon_empire', 'guildTypeId': 'NORMAL', 'stats': [{'nameKey': 'STAT_GALACTIC_POWER_ACQUIRED_NAME', 'value': 2773239, 'index': 1}, {'nameKey': 'STAT_CHARACTER_GALACTIC_POWER_ACQUIRED_NAME', 'value': 1641132, 'index': 2}, {'nameKey': 'STAT_SHIP_GALACTIC_POWER_ACQUIRED_NAME', 'value': 1135823, 'index': 3}, {'nameKey': 'STAT_SEASON_LEAGUE_SCORE_NAME', 'value': 0, 'index': 4}, {'nameKey': 'STAT_PVP_SHIP_BATTLES_WIN_NAME', 'value': 1584, 'index': 5}, {'nameKey': 'STAT_PVP_BATTLES_WIN_NAME_TU07_2', 'value': 2286, 'index': 6}, {'nameKey': 'STAT_PVE_BATTLES_WIN_NAME_TU15', 'value': 61501, 'index': 7}, {'nameKey': 'STAT_PVE_HARD_BATTLES_WIN_NAME_TU07_2', 'value': 24671, 'index': 8}, {'nameKey': 'STAT_TOTAL_GALACTIC_WON_NAME_TU07_2', 'value': 6057, 'index': 9}, {'nameKey': 'STAT_GUILD_RAID_WON_NAME_TU07_2', 'value': 432, 'index': 10}, {'nameKey': 'STAT_TOTAL_GUILD_CONTRIBUTION_NAME_TU07_2', 'value': 706316, 'index': 11}, {'nameKey': 'STAT_TOTAL_GUILD_EXCHANGE_DONATIONS_TU07_2', 'value': 2212, 'index': 12}, {'nameKey': 'STAT_SEASON_PROMOTIONS_EARNED_NAME', 'value': 0, 'index': 13}, {'nameKey': 'STAT_SEASON_OFFENSIVE_BATTLES_WON_NAME', 'value': 131, 'index': 14}, {'nameKey': 'STAT_SEASON_SUCCESSFUL_DEFENDS_NAME', 'value': 33, 'index': 15}, {'nameKey': 'STAT_SEASON_BANNERS_EARNED_NAME', 'value': 31883, 'index': 16}, {'nameKey': 'STAT_SEASON_FULL_CLEAR_ROUND_WINS_NAME', 'value': 13, 'index': 17}, {'nameKey': 'STAT_SEASON_UNDERSIZED_SQUAD_WINS_NAME', 'value': 44, 'index': 18}, {'nameKey': 'STAT_SEASON_TERRITORIES_DEFEATED_NAME', 'value': 57, 'index': 19}, {'nameKey': 'STAT_SEASON_MOST_LEAGUE_SCORE_NAME', 'value': 0, 'index': 20}, {'nameKey': 'STAT_SEASON_BEST_RANK_NAME', 'value': 0, 'index': 21}], 'roster': [{'id': 'N-FUzJLqRiuBpan6GYbwtw', 'defId': 'MAGMATROOPER', 'nameKey': 'UNIT_MAGMATROOPER_NAME', 'rarity': 5, 'level': 36, 'xp': 10950, 'gear': 4, 'equipped': [{'equipmentId': '050', 'slot': 0, 'nameKey': 'EQUIPMENT_050_NAME'}, {'equipmentId': '060', 'slot': 1, 'nameKey': 'EQUIPMENT_060_NAME'}, {'equipmentId': '062', 'slot': 2, 'nameKey': 'EQUIPMENT_062_NAME'}, {'equipmentId': '068', 'slot': 4, 'nameKey': 'EQUIPMENT_068_NAME'}], 'combatType': 1, 'skills': [{'id': 'specialskill_MAGMATROOPER01', 'tier': 3, 'nameKey': 'SPECIALABILITY_MAGMATROOPER01_NAME', 'isZeta': False}, {'id': 'basicskill_MAGMATROOPER', 'tier': 3, 'nameKey': 'BASICABILITY_MAGMATROOPER_NAME', 'isZeta': False}, {'id': 'uniqueskill_MAGMATROOPER01', 'tier': 3, 'nameKey': 'UNIQUEABILITY_MAGMATROOPER01_NAME', 'isZeta': False}], 'mods': [], 'crew': [], 'gp': 2699}, {'id': 'DjQlMEvPQ7GkkA38dJnEiQ', 'defId': 'HERMITYODA', 'nameKey': 'UNIT_HERMITYODA_NAME', 'rarity': 5, 'level': 85, 'xp': 883025, 'gear': 7, 'equipped': [{'equipmentId': '107', 'slot': 0, 'nameKey': 'EQUIPMENT_107_NAME'}, {'equipmentId': '105', 'slot': 1, 'nameKey': 'EQUIPMENT_105_NAME'}, {'equipmentId': '095', 'slot': 2, 'nameKey': 'EQUIPMENT_095_NAME'}, {'equipmentId': '095', 'slot': 3, 'nameKey': 'EQUIPMENT_095_NAME'}], 'combatType': 1, 'skills': [{'id': 'basicskill_HERMITYODA', 'tier': 7, 'nameKey': 'BASICABILITY_HERMITYODA_NAME', 'isZeta': False}, {'id': 'specialskill_HERMITYODA01', 'tier': 7, 'nameKey': 'SPECIALABILITY_HERMITYODA01_NAME', 'isZeta': False}, {'id': 'specialskill_HERMITYODA02', 'tier': 7, 'nameKey': 'SPECIALABILITY_HERMITYODA02_NAME', 'isZeta': True}, {'id': 'uniqueskill_HERMITYODA01', 'tier': 7, 'nameKey': ' ...
